# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from llama_index.core import VectorStoreIndex, StorageContext, SimpleDirectoryReader
# from llama_index.storage.storage_context import StorageContext
from llama_index.vector_stores.qdrant import QdrantVectorStore
from llama_index.core.node_parser import SentenceSplitter
import logging

logging.basicConfig(level=logging.INFO)

# %% [markdown]
# Check default settings

# %%
from llama_index.core import Settings

Settings.text_splitter
# Out:
# SentenceSplitter(include_metadata=True, include_prev_next_rel=True, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x7fcf10393700>, id_func=<function default_id_func at 0x7fcec9365dc0>, chunk_size=1024, chunk_overlap=200, separator=' ', paragraph_separator='\n\n\n', secondary_chunking_regex='[^,.;。？！]+[,.;。？！]?')

# %% [markdown]
# Important: This default `text_splitter` will be used to convert documents to nodes.
#
# It will also happen when we save in the `VectorStoreIndex`. LlamaIndex will automatically turn documents into nodes.

# %% [markdown]
# ### Load Documents

# %%
DATA_DIR = "/home/kris/dev/syenza-docs/pdfs-tests"

documents = SimpleDirectoryReader(DATA_DIR).load_data()

nodes = SentenceSplitter().get_nodes_from_documents(documents)

# %%
len(documents), len(nodes)
# Out:
# (28, 78)

# %% [markdown]
# Count tokens for documents

# %%
import tiktoken

embedding = tiktoken.get_encoding("cl100k_base")

# %%
for doc in documents:
    print(len(embedding.encode(doc.text)))
# Out:
# 1392
# 1323
# 1445
# 1166
# 1786
# 1718
# 1495
# 1109
# 1041
# 940
# 1291
# 886
# 1009
# 1104
# 1028
# 965
# 1213
# 961
# 1402
# 1203
# 780
# 1646
# 725
# 990
# 971
# 1629
# 9596
# 15247

# %%
for node in nodes:
    tkn_count = len(embedding.encode(node.text))
    print(tkn_count)
    # if tkn_count > 950:
    #     print("Long one!!")
    #     print(node.text)
# Out:
# 948
# 628
# 938
# 563
# 911
# 726
# 735
# 624
# 938
# 957
# 74
# 924
# 912
# 240
# 941
# 742
# 948
# 332
# 942
# 292
# 940
# 924
# 498
# 886
# 679
# 443
# 847
# 283
# 846
# 378
# 965
# 954
# 440
# 961
# 949
# 637
# 935
# 433
# 780
# 813
# 927
# 725
# 862
# 268
# 971
# 930
# 876
# 967
# 919
# 811
# 890
# 969
# 977
# 958
# 956
# 975
# 954
# 975
# 930
# 785
# 911
# 859
# 989
# 987
# 925
# 978
# 980
# 873
# 977
# 903
# 940
# 844
# 909
# 910
# 981
# 805
# 967
# 919

# %% [markdown]
# ### Qdrant Client
#
# For localhost

# %%
from qdrant_client import QdrantClient

client = QdrantClient(url="http://localhost:6333")

# %%
vector_store = QdrantVectorStore(client=client, collection_name="second_test")
storage_context = StorageContext.from_defaults(vector_store=vector_store)
index = VectorStoreIndex.from_documents(
    documents,
    storage_context=storage_context,
)
# Out:
# INFO:httpx:HTTP Request: GET http://localhost:6333/collections/second_test/exists "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: PUT http://localhost:6333/collections/second_test "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: PUT http://localhost:6333/collections/second_test/index?wait=true "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET http://localhost:6333/collections/second_test/exists "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET http://localhost:6333/collections/second_test "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: PUT http://localhost:6333/collections/second_test/points?wait=true "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: PUT http://localhost:6333/collections/second_test/points?wait=true "HTTP/1.1 200 OK"

# %% [markdown]
# ### Query Vector Store

# %%
# set Logging to DEBUG for more detailed outputs
query_engine = index.as_query_engine()
response = query_engine.query("What did the author do growing up?")
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://localhost:6333/collections/second_test/points/search "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"

# %%
response
# Out:
# Response(response='The author explained that growing up, they were involved in a variety of activities such as sports, music, and volunteering.', source_nodes=[NodeWithScore(node=TextNode(id_='b351f3a4-e72a-409f-8ac7-0d0dcf24c436', embedding=None, metadata={'file_name': 'Brazil.docx', 'file_path': '/home/kris/dev/syenza-docs/pdfs-tests/Brazil.docx', 'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'file_size': 62329, 'creation_date': '2024-07-11', 'last_modified_date': '2023-11-18'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='92e30d14-eb00-4f49-ad88-6d1d01a27373', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_name': 'Brazil.docx', 'file_path': '/home/kris/dev/syenza-docs/pdfs-tests/Brazil.docx', 'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'file_size': 62329, 'creation_date': '2024-07-11', 'last_modified_date': '2023-11-18'}, hash='ab92b6135a7d00f881943dd2c723d4b8cdd62ed38585d8beb9920c558c97d275'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='2c9f5ef1-c330-4334-9f30-a2d78ae97458', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='530bb34e3b1813d05c0c7a2998fb723dca6de8bf021000677cc59365ff95f220')}, text="Brazil Interview 091023\n\nMon, Oct 09, 2023 6:45PM • 48:38\n\nSUMMARY KEYWORDS\n\nvalve, patients, mitral, surgery, years, call, magna, prosthesis, Brazil, brazil, biological, mitral valve surgery, perfect, practice, difference, key opinion leaders, surgeon, durability, questions, interview\n\nSPEAKERS\n\nBrazil, João Carapinha, Danélia Botes\n\n\n\nDanélia Botes  00:00\n\nLike, they were thinking we were crooks. Like they were suspect from the get go, I remember their finance guy would call me and stuff. \n\n\n\nJoão Carapinha  00:06\n\nYeah.\n\n\n\nDanélia Botes  00:07\n\nAnd I Googled him, he looks like he's the owner's son. \n\n\n\nJoão Carapinha  00:12\n\nOh, I see.\n\n\n\nDanélia Botes  00:12\n\nBut he's like a production manager or something. So I don't know why he's the one that makes the call whether they do international transfers and stuff. But I mean, I explained to him on that phone call that it's going to be money from the US, and it's going to be international transfer and I said, you'll see it on your bank statement as well. \n\n\n\nJoão Carapinha  00:26\n\nYeah.\n\n\n\nDanélia Botes  00:28\n\nSo how does he think international money is going to come into his bank account without you know signing anything or you know, to my knowledge, you cannot get international money to your account, if you don't like declare it with the what's that email that we sent for that the bank sent?\n\n\n\nJoão Carapinha  00:48\n\nYeah, that the the bank send its exchange for free?\n\n\n\nDanélia Botes  00:51\n\nYes. So the exchange bureau.\n\n\n\nJoão Carapinha  00:53\n\nYeah. \n\n\n\nDanélia Botes  00:54\n\nAs far as I'm aware, you cannot get money into a South African account without signing the document like that. \n\n\n\nJoão Carapinha  01:00\n\nYeah. \n\n\n\nDanélia Botes  01:01\n\nSo what was he thinking? If it was an issue? What if you should have said it at that point? And the way they replied to say we're not clicking on any links or filling in any forms? Okay, cool.\n\n\n\nJoão Carapinha  01:10\n\nYeah, yeah. It's, it seems that they they're not accustomed to receiving funds from external suppliers, or international suppliers specificly.\n\n\n\nDanélia Botes  01:21\n\nYeah, and it's kind of a small business, I wanted to support them, because I've worked with them before and, you know, had great experience with them before, but...\n\n\n\nJoão Carapinha  01:28\n\nyeah, \n\n\n\nDanélia Botes  01:28\n\nKind of get the feeling, you know, since ...

# %% [markdown]
# ### Retriever

# %%
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core.query_engine import RetrieverQueryEngine

retriever = VectorIndexRetriever(index, similarity_top_k=5)
query_engine_rt = RetrieverQueryEngine(retriever)

# %% [markdown]
# Get Response

# %%
response = query_engine_rt.query("What did the author do growing up?")
response
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://localhost:6333/collections/second_test/points/search "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Response(response='The author discussed interactions with a business regarding financial transactions and international transfers.', source_nodes=[NodeWithScore(node=TextNode(id_='b351f3a4-e72a-409f-8ac7-0d0dcf24c436', embedding=None, metadata={'file_name': 'Brazil.docx', 'file_path': '/home/kris/dev/syenza-docs/pdfs-tests/Brazil.docx', 'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'file_size': 62329, 'creation_date': '2024-07-11', 'last_modified_date': '2023-11-18'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='92e30d14-eb00-4f49-ad88-6d1d01a27373', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_name': 'Brazil.docx', 'file_path': '/home/kris/dev/syenza-docs/pdfs-tests/Brazil.docx', 'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'file_size': 62329, 'creation_date': '2024-07-11', 'last_modified_date': '2023-11-18'}, hash='ab92b6135a7d00f881943dd2c723d4b8cdd62ed38585d8beb9920c558c97d275'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='2c9f5ef1-c330-4334-9f30-a2d78ae97458', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='530bb34e3b1813d05c0c7a2998fb723dca6de8bf021000677cc59365ff95f220')}, text="Brazil Interview 091023\n\nMon, Oct 09, 2023 6:45PM • 48:38\n\nSUMMARY KEYWORDS\n\nvalve, patients, mitral, surgery, years, call, magna, prosthesis, Brazil, brazil, biological, mitral valve surgery, perfect, practice, difference, key opinion leaders, surgeon, durability, questions, interview\n\nSPEAKERS\n\nBrazil, João Carapinha, Danélia Botes\n\n\n\nDanélia Botes  00:00\n\nLike, they were thinking we were crooks. Like they were suspect from the get go, I remember their finance guy would call me and stuff. \n\n\n\nJoão Carapinha  00:06\n\nYeah.\n\n\n\nDanélia Botes  00:07\n\nAnd I Googled him, he looks like he's the owner's son. \n\n\n\nJoão Carapinha  00:12\n\nOh, I see.\n\n\n\nDanélia Botes  00:12\n\nBut he's like a production manager or something. So I don't know why he's the one that makes the call whether they do international transfers and stuff. But I mean, I explained to him on that phone call that it's going to be money from the US, and it's going to be international transfer and I said, you'll see it on your bank statement as well. \n\n\n\nJoão Carapinha  00:26\n\nYeah.\n\n\n\nDanélia Botes  00:28\n\nSo how does he think international money is going to come into his bank account without you know signing anything or you know, to my knowledge, you cannot get international money to your account, if you don't like declare it with the what's that email that we sent for that the bank sent?\n\n\n\nJoão Carapinha  00:48\n\nYeah, that the the bank send its exchange for free?\n\n\n\nDanélia Botes  00:51\n\nYes. So the exchange bureau.\n\n\n\nJoão Carapinha  00:53\n\nYeah. \n\n\n\nDanélia Botes  00:54\n\nAs far as I'm aware, you cannot get money into a South African account without signing the document like that. \n\n\n\nJoão Carapinha  01:00\n\nYeah. \n\n\n\nDanélia Botes  01:01\n\nSo what was he thinking? If it was an issue? What if you should have said it at that point? And the way they replied to say we're not clicking on any links or filling in any forms? Okay, cool.\n\n\n\nJoão Carapinha  01:10\n\nYeah, yeah. It's, it seems that they they're not accustomed to receiving funds from external suppliers, or international suppliers specificly.\n\n\n\nDanélia Botes  01:21\n\nYeah, and it's kind of a small business, I wanted to support them, because I've worked with them before and, you know, had great experience with them before, but...\n\n\n\nJoão Carapinha  01:28\n\nyeah, \n\n\n\nDanélia Botes  01:28\n\nKind of get the feeling, you know, since the younger  ...

# %%
response.response
# Out:
# 'The author discussed interactions with a business regarding financial transactions and international transfers.'

# %% [markdown]
# Get Similar Nodes

# %%
retrieved_nodes = query_engine_rt.retrieve("What did the author do growing up?")
# Out:
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://localhost:6333/collections/second_test/points/search "HTTP/1.1 200 OK"

# %%
retrieved_nodes
# Out:
# [NodeWithScore(node=TextNode(id_='b351f3a4-e72a-409f-8ac7-0d0dcf24c436', embedding=None, metadata={'file_name': 'Brazil.docx', 'file_path': '/home/kris/dev/syenza-docs/pdfs-tests/Brazil.docx', 'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'file_size': 62329, 'creation_date': '2024-07-11', 'last_modified_date': '2023-11-18'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='92e30d14-eb00-4f49-ad88-6d1d01a27373', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_name': 'Brazil.docx', 'file_path': '/home/kris/dev/syenza-docs/pdfs-tests/Brazil.docx', 'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'file_size': 62329, 'creation_date': '2024-07-11', 'last_modified_date': '2023-11-18'}, hash='ab92b6135a7d00f881943dd2c723d4b8cdd62ed38585d8beb9920c558c97d275'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='2c9f5ef1-c330-4334-9f30-a2d78ae97458', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='530bb34e3b1813d05c0c7a2998fb723dca6de8bf021000677cc59365ff95f220')}, text="Brazil Interview 091023\n\nMon, Oct 09, 2023 6:45PM • 48:38\n\nSUMMARY KEYWORDS\n\nvalve, patients, mitral, surgery, years, call, magna, prosthesis, Brazil, brazil, biological, mitral valve surgery, perfect, practice, difference, key opinion leaders, surgeon, durability, questions, interview\n\nSPEAKERS\n\nBrazil, João Carapinha, Danélia Botes\n\n\n\nDanélia Botes  00:00\n\nLike, they were thinking we were crooks. Like they were suspect from the get go, I remember their finance guy would call me and stuff. \n\n\n\nJoão Carapinha  00:06\n\nYeah.\n\n\n\nDanélia Botes  00:07\n\nAnd I Googled him, he looks like he's the owner's son. \n\n\n\nJoão Carapinha  00:12\n\nOh, I see.\n\n\n\nDanélia Botes  00:12\n\nBut he's like a production manager or something. So I don't know why he's the one that makes the call whether they do international transfers and stuff. But I mean, I explained to him on that phone call that it's going to be money from the US, and it's going to be international transfer and I said, you'll see it on your bank statement as well. \n\n\n\nJoão Carapinha  00:26\n\nYeah.\n\n\n\nDanélia Botes  00:28\n\nSo how does he think international money is going to come into his bank account without you know signing anything or you know, to my knowledge, you cannot get international money to your account, if you don't like declare it with the what's that email that we sent for that the bank sent?\n\n\n\nJoão Carapinha  00:48\n\nYeah, that the the bank send its exchange for free?\n\n\n\nDanélia Botes  00:51\n\nYes. So the exchange bureau.\n\n\n\nJoão Carapinha  00:53\n\nYeah. \n\n\n\nDanélia Botes  00:54\n\nAs far as I'm aware, you cannot get money into a South African account without signing the document like that. \n\n\n\nJoão Carapinha  01:00\n\nYeah. \n\n\n\nDanélia Botes  01:01\n\nSo what was he thinking? If it was an issue? What if you should have said it at that point? And the way they replied to say we're not clicking on any links or filling in any forms? Okay, cool.\n\n\n\nJoão Carapinha  01:10\n\nYeah, yeah. It's, it seems that they they're not accustomed to receiving funds from external suppliers, or international suppliers specificly.\n\n\n\nDanélia Botes  01:21\n\nYeah, and it's kind of a small business, I wanted to support them, because I've worked with them before and, you know, had great experience with them before, but...\n\n\n\nJoão Carapinha  01:28\n\nyeah, \n\n\n\nDanélia Botes  01:28\n\nKind of get the feeling, you know, since the younger generation is taking over, I don't know. \n\n\n\nJoão Carapinha  01:34\n\nYeah, \n\n\n\nDanélia Botes  01:34\n\nIt's just been, it's not been plea ...
#  NodeWithScore(node=TextNode(id_='6c0c4d98-bf5c-4abf-bfef-2a732d59c10a', embedding=None, metadata={'file_name': 'Brazil.docx', 'file_path': '/home/kris/dev/syenza-docs/pdfs-tests/Brazil.docx', 'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'file_size': 62329, 'creation_date': '2024-07-11', 'last_modified_date': '2023-11-18'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='92e30d14-eb00-4f49-ad88-6d1d01a27373', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_name': 'Brazil.docx', 'file_path': '/home/kris/dev/syenza-docs/pdfs-tests/Brazil.docx', 'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'file_size': 62329, 'creation_date': '2024-07-11', 'last_modified_date': '2023-11-18'}, hash='ab92b6135a7d00f881943dd2c723d4b8cdd62ed38585d8beb9920c558c97d275'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='be1a0869-d695-4a19-8544-b49376721db4', node_type=<ObjectType.TEXT: '1'>, metadata={'file_name': 'Brazil.docx', 'file_path': '/home/kris/dev/syenza-docs/pdfs-tests/Brazil.docx', 'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'file_size': 62329, 'creation_date': '2024-07-11', 'last_modified_date': '2023-11-18'}, hash='b99e507763ddcf5f829bce50e94074ca87138ca2b2b069db64a999c143745fbe'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='7839dfd1-aa70-48df-a7e8-662006ca44d5', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='c730d969a98260a7b2c4e589911f186bf671fa5ae6c0baa01eb02e07428cc7ff')}, text="Danélia Botes  07:09\n\nThanks, Joao.  Hi, Brazil.  I'm Danelia,  I am the medical writer at Syenza.  I'm also a qualified pharmacist. So I just want to confirm if you've received the email, I've sent over with the information, the feedback that we've gotten so far with the key opinion leaders and the questions that we will be discussing today. \n\n\n\nBrazil  07:09\n\nThank you. Yes, I received it.\n\n\n\nDanélia Botes  07:30\n\nAlright, perfect. So the flow of today is basically what we call a Delphi panel discussion. So we will interview key opinion leaders, and then we get the feedback, we integrate it, send it over to the next person and see if there is commonalities or disagreements and see if we can find a form of consensus during this interview process. So like Joao said before, we've interviewed quite a few other specialists, and now we're going on to you to see if you can agree or disagree with some of the things that have been said. So we've divided the questions into three sections. So we talk about better outcomes in mitral valve surgery, we talk about mitral valve decision making what leads your decision making skills there. And then also talk about a specific of the MITRIS RESILIA valve.  Just to confirm this, this valve is not available in your country as of yet. If I'm correct, right?\n\n\n\nBrazil  08:19\n\nFew time. This is available in our country, we the MITRIS received the approval of government for something like 30 days ago. \n\n\n\nDanélia Botes  08:35\n\nSure. Okay, that's great.\n\n\n\nBrazil  08:36\n\nJust one month. We have two cases, schedule yet, but I didn't do anyone.\n\n\n\nDanélia Botes  08:45\n\nAll right. So you are aware of the technology and have some background, at least of what it looks like and the benefits and so forth?\n\n\n\nBrazil  08:52\n\n Yeah. \n\n\n\nDanélia Botes  08:53\n\nSure.  Thanks, doctor. So before we start with the questions, if you don't mind if you're comfortable just to give us a little bit of background of the practice that you're currently working at maybe specifying if you do a minimally invasive and so forth, and then we can start with the questions if you' ...
#  NodeWithScore(node=TextNode(id_='be1a0869-d695-4a19-8544-b49376721db4', embedding=None, metadata={'file_name': 'Brazil.docx', 'file_path': '/home/kris/dev/syenza-docs/pdfs-tests/Brazil.docx', 'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'file_size': 62329, 'creation_date': '2024-07-11', 'last_modified_date': '2023-11-18'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='92e30d14-eb00-4f49-ad88-6d1d01a27373', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_name': 'Brazil.docx', 'file_path': '/home/kris/dev/syenza-docs/pdfs-tests/Brazil.docx', 'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'file_size': 62329, 'creation_date': '2024-07-11', 'last_modified_date': '2023-11-18'}, hash='ab92b6135a7d00f881943dd2c723d4b8cdd62ed38585d8beb9920c558c97d275'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='2c9f5ef1-c330-4334-9f30-a2d78ae97458', node_type=<ObjectType.TEXT: '1'>, metadata={'file_name': 'Brazil.docx', 'file_path': '/home/kris/dev/syenza-docs/pdfs-tests/Brazil.docx', 'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'file_size': 62329, 'creation_date': '2024-07-11', 'last_modified_date': '2023-11-18'}, hash='9b49079474fbb2c451e9c86c500edeaab3e44ffede4f2b50e789c3c8d7f6b6b5'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='6c0c4d98-bf5c-4abf-bfef-2a732d59c10a', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='1a98354bf17bd720ba2adced91ec8ddd8f1f419b05b3ecf9c5ad991050216413')}, text="João Carapinha  03:56\n\ndo Sue okay and then on top of law tip new sample one Prasad\n\n\n\nBrazil  04:00\n\nah, l we start the Mizel Sue Brazil\n\n\n\nJoão Carapinha  04:05\n\nboys is adamant no Frontera\n\n\n\nBrazil  04:10\n\nkiller Why\n\n\n\nJoão Carapinha  04:11\n\nis Atomy anti amateur? Follow an SRA file and put it on all software mistook the manually propagation of\n\n\n\nBrazil  04:22\n\nautomate, which is\n\n\n\nJoão Carapinha  04:23\n\nokay for fleas meant cinnamon Partain traditionally said I am English but you're not a new vocabulary you butterflied sobre especially that the interventional cardiology and cardiothoracic surgeon says annoying part the upper limbs faladi English? \n\n\n\nBrazil  04:42\n\nYes, yes. \n\n\n\nJoão Carapinha  04:44\n\nOkay. Absolutely. So, thank you, Brazil, for your availability.  The purpose or for the call was reaching out to check on your willingness to participate in research that we've been commissioned to do by Edwards Lifesciences the European office and it's a pleasure to be on the call today together with my colleague Danelia Botes at Syenza.  I thought perhaps to start off with I'd provide you some overview around the the purpose of the call, a little bit about Syenza and then handover immediately to Danelia to facilitate the interview, if that's okay with you?\n\n\n\nBrazil  05:24\n\nOkay, it's okay.\n\n\n\nJoão Carapinha  05:25\n\nOkay, perfect. So the research that we're doing is the mitral valve replacement. And it's been commissioned by Edwards Lifesciences. So we've been responsible for developing the interview questions, the interview guides, and also engaging with key opinion leaders internationally. So far, we've completed interviews in Canada, the Netherlands, UK, and Spain. And coming up this week, we've got interviews in Germany and also in Mexico, we're very happy to be on the call today to include Brazil as well. And the research focus is mitral valve replacement. But then also talking about MITRIS RESILIA, the new technology from Edwards Lifesciences. What I did want to mention is before we get started officially is that the conversation is private, and con ...
#  NodeWithScore(node=TextNode(id_='2f1b6b2e-cbe0-46a2-9162-3bed81eff93c', embedding=None, metadata={'file_name': 'Brazil.docx', 'file_path': '/home/kris/dev/syenza-docs/pdfs-tests/Brazil.docx', 'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'file_size': 62329, 'creation_date': '2024-07-11', 'last_modified_date': '2023-11-18'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='92e30d14-eb00-4f49-ad88-6d1d01a27373', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_name': 'Brazil.docx', 'file_path': '/home/kris/dev/syenza-docs/pdfs-tests/Brazil.docx', 'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'file_size': 62329, 'creation_date': '2024-07-11', 'last_modified_date': '2023-11-18'}, hash='ab92b6135a7d00f881943dd2c723d4b8cdd62ed38585d8beb9920c558c97d275'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='7839dfd1-aa70-48df-a7e8-662006ca44d5', node_type=<ObjectType.TEXT: '1'>, metadata={'file_name': 'Brazil.docx', 'file_path': '/home/kris/dev/syenza-docs/pdfs-tests/Brazil.docx', 'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'file_size': 62329, 'creation_date': '2024-07-11', 'last_modified_date': '2023-11-18'}, hash='36507bce103307311bc8b4b3283dc576fbbf7b2d60d413d5812e70df926b397e'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='3f2b07fc-cc86-44b3-a2cd-1a33bfc9bfb1', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='767084eee04ab8f12275dce31301f1cc2298565fe3200fff0001d441993f92e6')}, text="Danélia Botes  17:50\n\nOkay.\n\n\n\nBrazil  17:51\n\n The great majority of our patients are in the green, green, no gray zone of the 50s to the 70s.\n\n\n\nJoão Carapinha  18:00\n\nOkay.\n\n\n\nDanélia Botes  18:01\n\nOkay.\n\n\n\nBrazil  18:01\n\nIs this grey zone, but I think this pregnant woman, pregnant age woman and small kids, I put biological for clinical reasons.\n\n\n\nDanélia Botes  18:19\n\nOkay.  And then also just to ask doc in Brazil, do the patients have a say when it comes to decision making for the valve? Like do they ask for a mechanical or bioprosthetic valve? Or is it up to the surgeon to decide which valve is being used in the patients?\n\n\n\nBrazil  18:37\n\nNo, we asked for all patients, we discuss with all patients.  Sometimes they don't have no knowledge to understand these things.\n\n\n\nDanélia Botes  18:56\n\nSure.\n\n\n\nBrazil  18:56\n\nBut all cases we discuss with the patients and the families.\n\n\n\nDanélia Botes  19:02\n\nOkay. Sure. Does the funding also play a role, the funders that fund for the valves? Do they play a role in your decision making? Do they guide you as well? How does the funding work in Brazil?\n\n\n\nBrazil  19:17\n\nSorry, I didn't understand the...\n\n\n\nDanélia Botes  19:20\n\nSo you said in the public sector that you don't have access to the premium valves. So I guess in that sector, the private sector you maybe have more decision. You have more valves available, but then who decides in that sector which valves is available? Does the funding mechanisms, the medical insurance also play a role?\n\n\n\nBrazil  19:43\n\nIn the private we don't have problem. We use what I want. But in public health we have just one brand in my hospital I don't have choice. I just choose mechanical or biological.\n\n\n\nDanélia Botes  20:10\n\nOkay, perfect. And then when it comes to biological valves, do you have a preference for bovine versus porcine?\n\n\n\nBrazil  20:20\n\nUntil five years ago, or better, eight years ago, we have a few repairs mitral repairs. So we use a lot of porcine valves, a lot of mosaic valve, Biocare from St. Jude's now Abbott, in mosaic valves.  With the r ...
#  NodeWithScore(node=TextNode(id_='2c9f5ef1-c330-4334-9f30-a2d78ae97458', embedding=None, metadata={'file_name': 'Brazil.docx', 'file_path': '/home/kris/dev/syenza-docs/pdfs-tests/Brazil.docx', 'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'file_size': 62329, 'creation_date': '2024-07-11', 'last_modified_date': '2023-11-18'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='92e30d14-eb00-4f49-ad88-6d1d01a27373', node_type=<ObjectType.DOCUMENT: '4'>, metadata={'file_name': 'Brazil.docx', 'file_path': '/home/kris/dev/syenza-docs/pdfs-tests/Brazil.docx', 'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'file_size': 62329, 'creation_date': '2024-07-11', 'last_modified_date': '2023-11-18'}, hash='ab92b6135a7d00f881943dd2c723d4b8cdd62ed38585d8beb9920c558c97d275'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='b351f3a4-e72a-409f-8ac7-0d0dcf24c436', node_type=<ObjectType.TEXT: '1'>, metadata={'file_name': 'Brazil.docx', 'file_path': '/home/kris/dev/syenza-docs/pdfs-tests/Brazil.docx', 'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'file_size': 62329, 'creation_date': '2024-07-11', 'last_modified_date': '2023-11-18'}, hash='cbd70920369e08bfac900fd6b806e705a4113c85a2fea3adafef84163a7dcbe4'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='be1a0869-d695-4a19-8544-b49376721db4', node_type=<ObjectType.TEXT: '1'>, metadata={}, hash='4d1cc478d87b99e8e771fd99ce61b2e0ddb0dcd2a11c12a9ca7e3331c6479825')}, text="Danélia Botes  01:55\n\nI doubt, their website doesn't look like that sort of thing. And I mean, if they are dodgy with clicking on links, I don't think.\n\n\n\nJoão Carapinha  02:02\n\n Yeah.\n\n\n\nDanélia Botes  02:02\n\nWe'll have that kind of technology available with the two other people that are waiting to today look like they have like all sorts of cool technology, how you can request quotes and stuff. So the one is, is just around the corner from me. So if I do go with her, it should be fairly fast. \n\n\n\nJoão Carapinha  02:06\n\nOkay.\n\n\n\nDanélia Botes  02:11\n\nAnd I'm working also with referrals, people that have used these people before.\n\n\n\nJoão Carapinha  02:23\n\nOkay. \n\n\n\nDanélia Botes  02:25\n\nSo, yeah.\n\n\n\nJoão Carapinha  02:26\n\nThat's always useful.\n\n\n\nDanélia Botes  02:27\n\nTo be certain are sorted out, yeah.  No, I just, I emailed them back to say, I'm disappointed in the interaction with you guys. And actually, I like I said, I want to phone the manager and just tell him at some point.\n\n\n\nJoão Carapinha  02:37\n\nYeah, \n\n\n\nDanélia Botes  02:37\n\nYou know, from the get go, you made me feel like I'm a crook. You know, when I was asking for the VAT number and stuff you were like, Why do you need that kind of a, you know, very suspect.\n\n\n\nJoão Carapinha  02:46\n\nYeah. \n\n\n\nDanélia Botes  02:47\n\nSo that's not a good way to handle clients. Yeah, no, \n\n\n\nJoão Carapinha  02:50\n\nNo, no, not at all. But it's okay. I mean, they're not the only business card suppliers in the world.   I mean, there's...\n\n\n\nDanélia Botes  02:55\n\n For sure.\n\n\n\nJoão Carapinha  02:57\n\nThere's substitutes, but I hear a bing bing did something?\n\n\n\nDanélia Botes  03:04\n\nYeah. There he is. Yeah, he is.\n\n\n\nJoão Carapinha  03:07\n\nIt's time to rock and roll. \n\n\n\nDanélia Botes  03:10\n\nYeah. \n\n\n\nJoão Carapinha  03:10\n\nAll good. And let me just open up the internal notes and great here we go.  It's going to be in Portuguese so follow along.\n\n\n\nDanélia Botes  03:21\n\nJust give me a thumbs up when it's my turn to talk.\n\n\n\nJoão Carapinha  03:25\n\na lab o ...

# %%
for node in retrieved_nodes:
    print(node.score, node.text)
# Out:
# 0.71907055 Brazil Interview 091023
#
# Mon, Oct 09, 2023 6:45PM • 48:38
#
# SUMMARY KEYWORDS
#
# valve, patients, mitral, surgery, years, call, magna, prosthesis, Brazil, brazil, biological, mitral valve surgery, perfect, practice, difference, key opinion leaders, surgeon, durability, questions, interview
#
# SPEAKERS
#
# Brazil, João Carapinha, Danélia Botes
#
#
#
# Danélia Botes  00:00
#
# Like, they were thinking we were crooks. Like they were suspect from the get go, I remember their finance guy would call me and stuff.
#
#
#
# João Carapinha  00:06
#
# Yeah.
#
#
#
# Danélia Botes  00:07
#
# And I Googled him, he looks like he's the owner's son.
#
#
#
# João Carapinha  00:12
#
# Oh, I see.
#
#
#
# Danélia Botes  00:12
#
# But he's like a production manager or something. So I don't know why he's the one that makes the call whether they do international transfers and stuff. But I mean, I explained to him on that phone call that it's going to be money from the US, and it's going to be international transfer and I said, you'll see it on your bank statement as well.
#
#
#
# João Carapinha  00:26
#
# Yeah.
#
#
#
# Danélia Botes  00:28
#
# So how does he think international money is going to come into his bank account without you know signing anything or you know, to my knowledge, you cannot get international money to your account, if you don't like declare it with the what's that email that we sent for that the bank sent?
#
#
#
# João Carapinha  00:48
#
# Yeah, that the the bank send its exchange for free?
#
#
#
# Danélia Botes  00:51
#
# Yes. So the exchange bureau.
#
#
#
# João Carapinha  00:53
#
# Yeah.
#
#
#
# Danélia Botes  00:54
#
# As far as I'm aware, you cannot get money into a South African account without signing the document like that.
#
#
#
# João Carapinha  01:00
#
# Yeah.
#
#
#
# Danélia Botes  01:01
#
# So what was he thinking? If it was an issue? What if you should have said it at that point? And the way they replied to say we're not clicking on any links or filling in any forms? Okay, cool.
#
#
#
# João Carapinha  01:10
#
# Yeah, yeah. It's, it seems that they they're not accustomed to receiving funds from external suppliers, or international suppliers specificly.
#
#
#
# Danélia Botes  01:21
#
# Yeah, and it's kind of a small business, I wanted to support them, because I've worked with them before and, you know, had great experience with them before, but...
#
#
#
# João Carapinha  01:28
#
# yeah,
#
#
#
# Danélia Botes  01:28
#
# Kind of get the feeling, you know, since the younger generation is taking over, I don't know.
#
#
#
# João Carapinha  01:34
#
# Yeah,
#
#
#
# Danélia Botes  01:34
#
# It's just been, it's not been pleasant, this experience.
#
#
#
# João Carapinha  01:37
#
# So unless they've got a lucky card processing facility of some sort, where they can do this online. In other words, you know, go online, and add a bundle of 100 business cards with graphic design and add them to a cart, and then checkout and do that sort of payment process.
#
#
#
# Danélia Botes  01:55
#
# I doubt, their website doesn't look like that sort of thing. And I mean, if they are dodgy with clicking on links, I don't think.
#
#
#
# João Carapinha  02:02
#
#  Yeah.
#
#
#
# Danélia Botes  02:02
#
# We'll have that kind of technology available with the two other people that are waiting to today look like they have like all sorts of cool technology, how you can request quotes and stuff. So the one is, is just around the corner from me. So if I do go with her, it should be fairly fast.
#
#
#
# João Carapinha  02:06
#
# Okay.
#
#
#
# Danélia Botes  02:11
#
# And I'm working also with referrals, people that have used these people before.
#
#
#
# João Carapinha  02:23
#
# Okay.
# 0.7158828 Danélia Botes  07:09
#
# Thanks, Joao.  Hi, Brazil.  I'm Danelia,  I am the medical writer at Syenza.  I'm also a qualified pharmacist. So I just want to confirm if you've received the email, I've sent over with the information, the feedback that we've gotten so far with the key opinion leaders and the questions that we will be discussing today.
#
#
#
# Brazil  07:09
#
# Thank you. Yes, I received it.
#
#
#
# Danélia Botes  07:30
#
# Alright, perfect. So the flow of today is basically what we call a Delphi panel discussion. So we will interview key opinion leaders, and then we get the feedback, we integrate it, send it over to the next person and see if there is commonalities or disagreements and see if we can find a form of consensus during this interview process. So like Joao said before, we've interviewed quite a few other specialists, and now we're going on to you to see if you can agree or disagree with some of the things that have been said. So we've divided the questions into three sections. So we talk about better outcomes in mitral valve surgery, we talk about mitral valve decision making what leads your decision making skills there. And then also talk about a specific of the MITRIS RESILIA valve.  Just to confirm this, this valve is not available in your country as of yet. If I'm correct, right?
#
#
#
# Brazil  08:19
#
# Few time. This is available in our country, we the MITRIS received the approval of government for something like 30 days ago.
#
#
#
# Danélia Botes  08:35
#
# Sure. Okay, that's great.
#
#
#
# Brazil  08:36
#
# Just one month. We have two cases, schedule yet, but I didn't do anyone.
#
#
#
# Danélia Botes  08:45
#
# All right. So you are aware of the technology and have some background, at least of what it looks like and the benefits and so forth?
#
#
#
# Brazil  08:52
#
#  Yeah.
#
#
#
# Danélia Botes  08:53
#
# Sure.  Thanks, doctor. So before we start with the questions, if you don't mind if you're comfortable just to give us a little bit of background of the practice that you're currently working at maybe specifying if you do a minimally invasive and so forth, and then we can start with the questions if you're comfortable.
#
#
#
# Brazil  09:07
#
# Okay. You want to answer the questions now? Are you asking me something is perceivable?
#
#
#
# Danélia Botes  09:23
#
# So if you can just first give us a little bit of an overview of the practice where you're currently working, just to say maybe what kind of surgeries you do if you do minimally invasive, robotic surgery just so we know that what your background is as well please, doctor?
#
#
#
# Brazil  09:38
#
# I am surgeon 20 years now. And I do a lot of surgeries per day. Something like 300, 305 by year I work in two hospitals, a public hospital and a private hospital. I do something like 70, 80 mitral surgeries by year, something like two per week without vacations etc. And we do mix surgery.  We do specifically valve surgery, mix and vascularization we do full sternotomy without mix, is something like that.  In our practice we have 75 to 80% of repair, mitral repair, few cases of mitral replacement.  We have in my state kind of patients something like Europe or North America.  We have a few cases of rheumatic heart disease but in the rest of country, Brazil, there's a high incidence of rheumatic disease.  There's a different kind of population but we have the almost the same problems with the social economic viability to the public service for premium, let's talk in this manner. Premium valves like my MITRIS like a Magna, like mosaic, we don't have this just kind of protheses in the public health just some brands, national brands like a brylee like a lobby card we have in the the public health.  In the private system, we have all kinds of protheses.
# 0.7137005 João Carapinha  03:56
#
# do Sue okay and then on top of law tip new sample one Prasad
#
#
#
# Brazil  04:00
#
# ah, l we start the Mizel Sue Brazil
#
#
#
# João Carapinha  04:05
#
# boys is adamant no Frontera
#
#
#
# Brazil  04:10
#
# killer Why
#
#
#
# João Carapinha  04:11
#
# is Atomy anti amateur? Follow an SRA file and put it on all software mistook the manually propagation of
#
#
#
# Brazil  04:22
#
# automate, which is
#
#
#
# João Carapinha  04:23
#
# okay for fleas meant cinnamon Partain traditionally said I am English but you're not a new vocabulary you butterflied sobre especially that the interventional cardiology and cardiothoracic surgeon says annoying part the upper limbs faladi English?
#
#
#
# Brazil  04:42
#
# Yes, yes.
#
#
#
# João Carapinha  04:44
#
# Okay. Absolutely. So, thank you, Brazil, for your availability.  The purpose or for the call was reaching out to check on your willingness to participate in research that we've been commissioned to do by Edwards Lifesciences the European office and it's a pleasure to be on the call today together with my colleague Danelia Botes at Syenza.  I thought perhaps to start off with I'd provide you some overview around the the purpose of the call, a little bit about Syenza and then handover immediately to Danelia to facilitate the interview, if that's okay with you?
#
#
#
# Brazil  05:24
#
# Okay, it's okay.
#
#
#
# João Carapinha  05:25
#
# Okay, perfect. So the research that we're doing is the mitral valve replacement. And it's been commissioned by Edwards Lifesciences. So we've been responsible for developing the interview questions, the interview guides, and also engaging with key opinion leaders internationally. So far, we've completed interviews in Canada, the Netherlands, UK, and Spain. And coming up this week, we've got interviews in Germany and also in Mexico, we're very happy to be on the call today to include Brazil as well. And the research focus is mitral valve replacement. But then also talking about MITRIS RESILIA, the new technology from Edwards Lifesciences. What I did want to mention is before we get started officially is that the conversation is private, and confidential.
#
#
#
# Brazil  06:13
#
# Okay.
#
#
#
# João Carapinha  06:14
#
# Anything that you share with us on the call will not be provided to Edwards Lifesciences verbatim. We only provide feedback to them in an aggregated form, together with the other key opinion leaders from the countries that are mentioned. And we're just interested in identifying main themes, commonalities and differences. So we welcome your positive opinions and also the negative opinions, right, if, if there are any, okay, we are Syenza. We're a USA based company. We focus on accelerating access to innovative healthcare technologies. Most of our research is on health economics and outcomes research, market access and dynamic intelligence. And I also have an affiliate to assistant professorship at Northeastern University in Boston. So with that being said, and being done, it's a real pleasure to be on the call today. Let me hand over to Danelia.
#
#
#
# Danélia Botes  07:09
#
# Thanks, Joao.  Hi, Brazil.  I'm Danelia,  I am the medical writer at Syenza.  I'm also a qualified pharmacist. So I just want to confirm if you've received the email, I've sent over with the information, the feedback that we've gotten so far with the key opinion leaders and the questions that we will be discussing today.
#
#
#
# Brazil  07:09
#
# Thank you. Yes, I received it.
# 0.7120516 Danélia Botes  17:50
#
# Okay.
#
#
#
# Brazil  17:51
#
#  The great majority of our patients are in the green, green, no gray zone of the 50s to the 70s.
#
#
#
# João Carapinha  18:00
#
# Okay.
#
#
#
# Danélia Botes  18:01
#
# Okay.
#
#
#
# Brazil  18:01
#
# Is this grey zone, but I think this pregnant woman, pregnant age woman and small kids, I put biological for clinical reasons.
#
#
#
# Danélia Botes  18:19
#
# Okay.  And then also just to ask doc in Brazil, do the patients have a say when it comes to decision making for the valve? Like do they ask for a mechanical or bioprosthetic valve? Or is it up to the surgeon to decide which valve is being used in the patients?
#
#
#
# Brazil  18:37
#
# No, we asked for all patients, we discuss with all patients.  Sometimes they don't have no knowledge to understand these things.
#
#
#
# Danélia Botes  18:56
#
# Sure.
#
#
#
# Brazil  18:56
#
# But all cases we discuss with the patients and the families.
#
#
#
# Danélia Botes  19:02
#
# Okay. Sure. Does the funding also play a role, the funders that fund for the valves? Do they play a role in your decision making? Do they guide you as well? How does the funding work in Brazil?
#
#
#
# Brazil  19:17
#
# Sorry, I didn't understand the...
#
#
#
# Danélia Botes  19:20
#
# So you said in the public sector that you don't have access to the premium valves. So I guess in that sector, the private sector you maybe have more decision. You have more valves available, but then who decides in that sector which valves is available? Does the funding mechanisms, the medical insurance also play a role?
#
#
#
# Brazil  19:43
#
# In the private we don't have problem. We use what I want. But in public health we have just one brand in my hospital I don't have choice. I just choose mechanical or biological.
#
#
#
# Danélia Botes  20:10
#
# Okay, perfect. And then when it comes to biological valves, do you have a preference for bovine versus porcine?
#
#
#
# Brazil  20:20
#
# Until five years ago, or better, eight years ago, we have a few repairs mitral repairs. So we use a lot of porcine valves, a lot of mosaic valve, Biocare from St. Jude's now Abbott, in mosaic valves.  With the repairs growing a lot, we start with the relationship with  Edwards because the fees are too and the cost growth bands. So we always have the  prosthesis for backup.   So, now use Magna, just because this I don't know, the word was facility is easy to us, because I have the valve. The day there's no a lot of the papers show the porcine is better, but not much better. So Magna is an excellent valvle. There's a better,  mother a mother named Mickey perfu no hyperfuse Bo, yeah. And small posts is better thinking probably a future valve in valve mitral.
#
#
#
# Danélia Botes  22:10
#
# Perfect. Do do you suspect if MITRIS RESILIA comes to the country and the durability of the valve is more? Do you expect a lot of better patient satisfaction of your patients in the hospital and a better quality of life? Or do you not see that making much of a difference from the patient side?
#
#
#
# Brazil  22:28
#
# I think that the patient will be better because a lot of patients today came to us asking for no take anticoagulants.
#
#
#
# Danélia Botes  22:42
#
# Sure.
#
#
#
# Brazil  22:44
#
# I think this conversation with your clinical cardiologist or the internet. So they asking for us for don't take Warfarin. So I think they will be happy with the RESILIA tissue.
#
#
#
# Danélia Botes  23:05
#
# Sure. I think that also sort of already asked but if the valve comes in at a bit of a high cost, do you expect it being troublesome to get it into your practice? Or you said that they usually you can use whatever valve you would like to in your patients?
#
#
#
# Brazil  23:24
#
# I think no, because we have to when I asked for a different type of different kinds of protheses, I have to argue with the payer. So if I have the adequate argue with the papers with the territory, there is no problem for us. I think there's no problem.
# 0.71068823 Danélia Botes  01:55
#
# I doubt, their website doesn't look like that sort of thing. And I mean, if they are dodgy with clicking on links, I don't think.
#
#
#
# João Carapinha  02:02
#
#  Yeah.
#
#
#
# Danélia Botes  02:02
#
# We'll have that kind of technology available with the two other people that are waiting to today look like they have like all sorts of cool technology, how you can request quotes and stuff. So the one is, is just around the corner from me. So if I do go with her, it should be fairly fast.
#
#
#
# João Carapinha  02:06
#
# Okay.
#
#
#
# Danélia Botes  02:11
#
# And I'm working also with referrals, people that have used these people before.
#
#
#
# João Carapinha  02:23
#
# Okay.
#
#
#
# Danélia Botes  02:25
#
# So, yeah.
#
#
#
# João Carapinha  02:26
#
# That's always useful.
#
#
#
# Danélia Botes  02:27
#
# To be certain are sorted out, yeah.  No, I just, I emailed them back to say, I'm disappointed in the interaction with you guys. And actually, I like I said, I want to phone the manager and just tell him at some point.
#
#
#
# João Carapinha  02:37
#
# Yeah,
#
#
#
# Danélia Botes  02:37
#
# You know, from the get go, you made me feel like I'm a crook. You know, when I was asking for the VAT number and stuff you were like, Why do you need that kind of a, you know, very suspect.
#
#
#
# João Carapinha  02:46
#
# Yeah.
#
#
#
# Danélia Botes  02:47
#
# So that's not a good way to handle clients. Yeah, no,
#
#
#
# João Carapinha  02:50
#
# No, no, not at all. But it's okay. I mean, they're not the only business card suppliers in the world.   I mean, there's...
#
#
#
# Danélia Botes  02:55
#
#  For sure.
#
#
#
# João Carapinha  02:57
#
# There's substitutes, but I hear a bing bing did something?
#
#
#
# Danélia Botes  03:04
#
# Yeah. There he is. Yeah, he is.
#
#
#
# João Carapinha  03:07
#
# It's time to rock and roll.
#
#
#
# Danélia Botes  03:10
#
# Yeah.
#
#
#
# João Carapinha  03:10
#
# All good. And let me just open up the internal notes and great here we go.  It's going to be in Portuguese so follow along.
#
#
#
# Danélia Botes  03:21
#
# Just give me a thumbs up when it's my turn to talk.
#
#
#
# João Carapinha  03:25
#
# a lab on the total legal kitao Today Allah, Allah the total time of it.
#
#
#
# Brazil  03:39
#
# Seeing.
#
#
#
# João Carapinha  03:39
#
#  all lab on deck today.
#
#
#
# Brazil  03:41
#
# Bone Jia Comstock was this
#
#
#
# João Carapinha  03:43
#
# yellow Stratos vein touch payment already got? Milan presented the contract which was tying some Paulo or Brasilia
#
#
#
# Brazil  03:54
#
# Hugh Grant to sue Rio Grande
#
#
#
# João Carapinha  03:56
#
# do Sue okay and then on top of law tip new sample one Prasad
#
#
#
# Brazil  04:00
#
# ah, l we start the Mizel Sue Brazil
#
#
#
# João Carapinha  04:05
#
# boys is adamant no Frontera
#
#
#
# Brazil  04:10
#
# killer Why
#
#
#
# João Carapinha  04:11
#
# is Atomy anti amateur? Follow an SRA file and put it on all software mistook the manually propagation of
#
#
#
# Brazil  04:22
#
# automate, which is
#
#
#
# João Carapinha  04:23
#
# okay for fleas meant cinnamon Partain traditionally said I am English but you're not a new vocabulary you butterflied sobre especially that the interventional cardiology and cardiothoracic surgeon says annoying part the upper limbs faladi English?
#
#
#
# Brazil  04:42
#
# Yes, yes.
